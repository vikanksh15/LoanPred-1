# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('FinalDataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0           0             5849                0.0       128.0
# 1           1             4583             1508.0       128.0
# 2           2             3000                0.0        66.0
# 3           3             2583             2358.0       120.0
# 4           4             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History  Gender_Male  Married_Yes  Dependents_1  \
# 0             360.0             1.0            1            0             0
# 1             360.0             1.0            1            1             1
# 2             360.0             1.0            1            1             0
# 3             360.0             1.0            1            1             0
# 4             360.0             1.0            1            0             0
#
#    Dependents_2  Dependents_3+  Education_Not Graduate  Self_Employed_Yes  \
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# ### Different statistics from our dataset:
# #### We will look into the relationship between the features and the target variable(Loan Status)

# %%
sns.pairplot(df)

# %%
# Loan Status
sns.countplot(x='Loan_Status_Y', data=df, palette='RdBu_r')

# %%
# Loan Status with Gender
sns.countplot(x='Loan_Status_Y', hue='Gender_Male', data=df, palette='RdBu_r')

# %%
# Loan Status with Credit History
sns.countplot(x='Loan_Status_Y', hue='Credit_History', data=df, palette='RdBu_r')

# %%
# Loan Status with Relationship Status
sns.countplot(x='Loan_Status_Y', hue='Married_Yes', data=df, palette='RdBu_r')

# %%
# Loan Status with Education Status
sns.countplot(x='Loan_Status_Y', hue='Education_Not Graduate', data=df, palette='RdBu_r')

# %%
# Loan Status with Education Status
sns.countplot(x='Loan_Status_Y', hue='Education_Not Graduate', data=df, palette='RdBu_r')

# %%
# Loan Status with Self-Employment status
sns.countplot(x='Loan_Status_Y', hue='Self_Employed_Yes', data=df, palette='RdBu_r')

# %%
# Loan Status with people living in Semi-urban properties
sns.countplot(x='Loan_Status_Y', hue='Property_Area_Semiurban', data=df, palette='RdBu_r')

# %%
# Loan Status with people living in Urban properties
sns.countplot(x='Loan_Status_Y', hue='Property_Area_Urban', data=df, palette='RdBu_r')

# %% [markdown]
# ## Creating the model:

# %% [markdown]
# ### 1. Logistic Regression

# %%
X = df.drop('Loan_Status_Y', axis=1)
y = df['Loan_Status_Y']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
predictions_Logistic = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
accuracy_score(y_test, predictions_Logistic)
# Out:
# 0.7684729064039408

# %%
def calculateMetrics(model):
    print(classification_report(y_test, model))
    print('\n')
    print(confusion_matrix(y_test, model))

# %%
calculateMetrics(predictions_Logistic)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.41      0.56        73
#            1       0.75      0.97      0.84       130
#
#     accuracy                           0.77       203
#    macro avg       0.81      0.69      0.70       203
# weighted avg       0.79      0.77      0.74       203
#
#
#
# [[ 30  43]
#  [  4 126]]

# %% [markdown]
# ### 2. Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_DT = DecisionTreeClassifier()

# %%
model_DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions_DT = model_DT.predict(X_test)

# %%
accuracy_score(y_test, predictions_DT)
# Out:
# 0.729064039408867

# %%
calculateMetrics(predictions_DT)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.47      0.55        73
#            1       0.75      0.88      0.81       130
#
#     accuracy                           0.73       203
#    macro avg       0.71      0.67      0.68       203
# weighted avg       0.72      0.73      0.71       203
#
#
#
# [[ 34  39]
#  [ 16 114]]

# %% [markdown]
# ### 3. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
## Creating hyper parameters:
#1. Number of trees in random forest
n_estimators=[int(x) for x in np.linspace(start=100, stop=1200, num=12)]
#2. Number of features to consider at every split
max_features = ['auto', 'sqrt']
#3. Maximum number of levels in the tree
max_depth = [int(x) for x in np.linspace(start=5, stop=30, num=6)]
#4. Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
#5. Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators' : n_estimators,
              'max_features' : max_features,
              'max_depth' : max_depth,
              'min_samples_split' : min_samples_split,
              'min_samples_leaf' : min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rf = RandomForestClassifier()

# %%
model_RF = RandomForestClassifier()

# %%
model_RF = RandomizedSearchCV(estimator = rf, param_distributions=random_grid, scoring='neg_mean_squared_error', n_iter=10, cv = 5, verbose=2, random_state=42, n_jobs=1)

# %%
model_RF.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.0s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.0s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   0.9s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# ...

# %%
model_RF.best_params_
# Out:
# {'n_estimators': 900,
#  'min_samples_split': 5,
#  'min_samples_leaf': 5,
#  'max_features': 'sqrt',
#  'max_depth': 10}

# %%
predictions_RF = model_RF.predict(X_test)

# %%
accuracy_score(y_test, predictions_RF)
# Out:
# 0.7733990147783252

# %%
calculateMetrics(predictions_RF)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.41      0.57        73
#            1       0.75      0.98      0.85       130
#
#     accuracy                           0.77       203
#    macro avg       0.83      0.69      0.71       203
# weighted avg       0.81      0.77      0.75       203
#
#
#
# [[ 30  43]
#  [  3 127]]

# %%
test_value = X.iloc[0]

# %%
model_DT.predict([test_value])
# Out:
# array([1])

# %% [markdown]
# ### Using SVM(Support Vector Machines)

# %%
from sklearn.svm import SVC

# %%
model_SVC = SVC(kernel='linear', random_state=101)

# %%
model_SVC.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=101)

# %%
predictions_SVM = model_SVC.predict(X_test)

# %%
print("Accuracy score for Support Vector machine is ", accuracy_score(y_test, predictions_SVM))
# Out:
# Accuracy score for Support Vector machine is  0.7142857142857143

# %%
calculateMetrics(predictions_SVM)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.25      0.38        73
#            1       0.70      0.98      0.81       130
#
#     accuracy                           0.71       203
#    macro avg       0.78      0.61      0.60       203
# weighted avg       0.76      0.71      0.66       203
#
#
#
# [[ 18  55]
#  [  3 127]]

# %% [markdown]
# ### Using XGBoost

# %%
import xgboost as xgb
from xgboost.sklearn import XGBClassifier

# %%
xgb1 = XGBClassifier(learning_rate = 0.1,
                     n_estimators = 1000,
                     max_depth=5,
                     min_child_weight = 1,
                     gamma=0,
                     subsample=0.8,
                     colsample_bytree = 0.8,
                     objective = 'binary:logistic',
                     nthread=4,
                     scale_pos_weight = 1,
                     seed = 27)

# %%
xgb1.fit(X_train, y_train)
# Out:
# [23:40:00] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/jackson/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
# ...

# %%
predictions_XGB = xgb1.predict(X_test)

# %%
print("Accuracy score for XGBoost is ", accuracy_score(y_test, predictions_XGB))
# Out:
# Accuracy score for XGBoost is  0.7093596059113301

# %%
calculateMetrics(predictions_XGB)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.42      0.51        73
#            1       0.73      0.87      0.79       130
#
#     accuracy                           0.71       203
#    macro avg       0.69      0.65      0.65       203
# weighted avg       0.70      0.71      0.69       203
#
#
#
# [[ 31  42]
#  [ 17 113]]

# %% [markdown]
# ### Now we will try to tune the hyperparameters, so as to get more accuracy

# %%
from sklearn.model_selection import GridSearchCV

# %%
para_test1 = {
    'max_depth' : [4, 5, 6],
    'min_child_weight' : [4, 5, 6]
}

# %%
gsearch2 = GridSearchCV(estimator = XGBClassifier(
                                            learning_rate=0.1,
                                            n_estimators=140,
                                            max_depth=5,
                                            min_child_weight=1,
                                            gamma=0,
                                            subsample=0.8,
                                            colsample_bytree=0.8,
                                            objective='binary:logistic',
                                            nthread=4,
                                            scale_pos_weight=1,
                                            seed=27),
                        param_grid=para_test1,
                        scoring='roc_auc',
                        n_jobs=4, 
                        iid=False,
                        cv=5)

# %%
gsearch2.fit(X_train, y_train)
# Out:
# [23:40:30] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/jackson/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# /home/jackson/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# GridSearchCV(cv=5,
# ...

# %%
print(gsearch2.best_params_)
print(gsearch2.best_score_)
# Out:
# {'max_depth': 6, 'min_child_weight': 4}
# 0.7551922132154262
